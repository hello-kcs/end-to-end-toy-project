# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# During preprocessing, as there were no missing values in any column, only the 'Unnamed: 0' index column was removed."

# %%
df = df.iloc[:, 1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %% [markdown]
# For EDA

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %% [markdown]
# extract input and output column

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 75   4.8  169.0
# 35   6.8   90.0
# 84   5.7  169.0
# 7    5.0   63.0
# 95   4.3  200.0
# ..   ...    ...
# 24   4.7  121.0
# 62   6.0  102.0
# 20   6.6  120.0
# 88   4.4  149.0
# 71   6.1  132.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 75    0
# 35    1
# 84    0
# 7     0
# 95    0
#      ..
# 24    0
# 62    0
# 20    1
# 88    0
# 71    1
# Name: placement, Length: 90, dtype: int64

# %% [markdown]
# scaling the values
# [link text](https://)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_train
# Out:
# array([[-1.1361801 ,  1.12320655],
#        [ 0.6530799 , -0.92869442],
#        [-0.3310131 ,  1.12320655],
#        [-0.9572541 , -1.62997703],
#        [-1.58349509,  1.92838288],
#        [ 1.1003949 , -1.96763162],
#        [-1.1361801 ,  0.39595051],
#        [-0.9572541 , -0.20143838],
#        [ 0.5636169 ,  0.7336051 ],
#        [ 0.0268389 ,  0.78555196],
#        [ 0.2057649 ,  0.05829592],
#        [-0.5994021 ,  0.34400365],
#        [ 0.7425429 ,  0.34400365],
#        [ 1.2793209 , -1.68192389],
#        [-0.7783281 ,  0.16218964],
#        [ 0.8320059 , -1.6040036 ],
#        [ 0.8320059 , -0.35727896],
#        [-0.0626241 , -0.0455978 ],
#        [-1.0467171 , -0.14949152],
#        [-0.0626241 , -1.55205674],
#        [-2.29919909,  2.78550607],
#        [ 0.3846909 ,  0.11024278],
#        [ 0.5636169 ,  1.46086114],
#        [-1.0467171 ,  1.82448916],
#        [-0.3310131 ,  0.36997708],
#        [ 1.2793209 ,  0.83749882],
#        [-0.8677911 ,  1.30502056],
#        [ 1.81609889,  1.04528626],
#        [ 0.2952279 ,  0.39595051],
#        [ 1.81609889,  0.60373795],
#        [-0.1520871 , -0.51311954],
#        [-0.7783281 , -0.40922582],
#        [-1.2256431 , -1.91568476],
#        [-1.3151061 ,  0.52581766],
#        [-1.94134709, -0.43519925],
#        [-1.0467171 ,  0.75957853],
#        [ 0.3846909 , -2.30528621],
#        [-1.0467171 , -1.68192389],
#        [ 1.2793209 ,  0.11024278],
#        [-1.1361801 ,  0.96736597],
#        [-0.8677911 , -1.55205674],
#        [-0.7783281 , -0.92869442],
#        [ 0.4741539 ,  0.31803022],
#        [-1.1361801 , -0.35727896],
#        [ 1.99502489,  1.09723312],
#        [-0.3310131 ,  0.16218964],
#        [ 1.3687839 , -0.95466785],
#        [ 1.54770989, -0.3053321 ],
#        [ 0.6530799 , -0.07157123],
#        [ 0.2952279 , -0.25338524],
#        [ 0.2057649 ,  0.03232249],
#        [ 0.6530799 , -0.35727896],
#        [ 1.1003949 , -1.03258814],
#        [ 1.72663589, -1.21440215],
#        [ 1.1003949 , -0.25338524],
#        [ 0.8320059 ,  1.27904713],
#        [ 1.3687839 ,  0.05829592],
#        [-0.7783281 ,  0.91541911],
#        [ 0.6530799 ,  0.39595051],
#        [-0.6888651 , -0.12351809],
#        [ 0.8320059 ,  1.90240945],
#        [-1.0467171 ,  0.65568481],
#        [-0.5994021 , -0.3053321 ],
#        [ 2.17395089, -0.14949152],
#        [-0.2415501 ,  0.42192394],
#        [ 0.7425429 , -0.77285384],
#        [-1.85188409, -1.31829587],
#        [ 0.1163019 , -0.33130553],
#        [ 0.2057649 , -0.59103983],
#        [-1.2256431 , -1.00661471],
#        [-0.6888651 , -0.3053321 ],
#        [ 0.9214689 ,  0.65568481],
#        [ 0.3846909 ,  0.88944568],
#        [-0.9572541 , -0.90272099],
#        [-1.0467171 ,  0.2141365 ],
#        [ 0.7425429 ,  0.31803022],
#        [-0.3310131 ,  0.44789737],
#        [ 0.0268389 , -1.57803017],
#        [ 1.1003949 ,  0.29205679],
#        [-0.2415501 ,  1.04528626],
#        [ 0.3846909 , -0.92869442],
#        [-0.7783281 ,  2.5517452 ],
#        [ 0.0268389 , -1.16245529],
#        [ 0.8320059 ,  0.34400365],
#        [ 1.1898579 ,  0.16218964],
#        [-1.2256431 , -0.12351809],
#        [-0.0626241 , -0.61701326],
#        [ 0.4741539 , -0.14949152],
#        [-1.49403209,  0.60373795],
#        [ 0.0268389 ,  0.16218964]])

# %%
X_test=scaler.transform(X_test)
X_test
# Out:
# array([[-0.5994021 , -0.48714611],
#        [-0.0626241 ,  0.60373795],
#        [-2.47812509,  1.48683457],
#        [-0.5994021 ,  0.24010993],
#        [-0.0626241 , -2.09749877],
#        [-1.49403209, -2.17541906],
#        [-1.85188409, -0.66896012],
#        [ 0.0268389 , -0.59103983],
#        [-0.8677911 ,  0.05829592],
#        [ 0.9214689 , -2.01957848]])

# %% [markdown]
# train the model

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# evaluate model

# %%
y_pred=clf.predict(X_test)

# %%
y_test
# Out:
# 81    0
# 33    0
# 17    0
# 49    0
# 10    1
# 96    0
# 18    0
# 14    0
# 86    0
# 5     1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle
pickle.dump(clf,open('model.pkl','wb'))
